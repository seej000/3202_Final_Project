# %%
# System Update and Swig Installation
# Updates the system packages in your environment and installs swig, a tool needed for building certain Python libraries.
# !apt-get update -qq
# !apt-get install -y swig
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 151 not upgraded.

# %%
# 2. Install Key Python Packages
# Installs specific versions of gym, box2d-py, and stable-baselines3. 
# These packages are required for running the LunarLander environment and the PPO reinforcement learning algorithm.
# !pip install "gym==0.26.2" "box2d-py==2.3.5" "stable-baselines3==2.0.0"
# Out:
# Requirement already satisfied: gym==0.26.2 in /usr/local/lib/python3.11/dist-packages (0.26.2)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.11/dist-packages (2.3.5)
# Requirement already satisfied: stable-baselines3==2.0.0 in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.26.2) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.26.2) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.26.2) (0.0.8)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (0.28.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (2.5.1+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0) (3.7.5)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (4.13.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->stable-baselines3==2.0.0) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.0->gym==0.26.2) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.0->gym==0.26.2) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.0->gym==0.26.2) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.0->gym==0.26.2) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.0->gym==0.26.2) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.0->gym==0.26.2) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11->stable-baselines3==2.0.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.0.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.0->gym==0.26.2) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.0->gym==0.26.2) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.0->gym==0.26.2) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.0->gym==0.26.2) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.0->gym==0.26.2) (2024.2.0)

# %%
# 3. Basic Environment Test (Step 1)
# Creates the LunarLander-v2 environment (with render_mode="rgb_array").
# Resets the environment and checks the shape of the initial observation (should be (8,)).

import gym

env = gym.make("LunarLander-v2", render_mode="rgb_array")
obs, info = env.reset()
print("Observation shape:", obs.shape)
env.close()
# Out:
# Observation shape: (8,)

# %%
# 4. Basic Environment Test (Step 2)
# After resetting, we sample one random action and step the environment forward.
# I then check the next observation’s shape, the immediate reward, and whether the episode has ended.

import gym

env = gym.make("LunarLander-v2", render_mode="rgb_array")
obs, info = env.reset()

print("Initial observation shape:", obs.shape)  # (8,) が出ればOK

action = env.action_space.sample()
next_obs, reward, done, truncated, _info = env.step(action)
print("Next observation shape:", next_obs.shape)
print("Reward:", reward)
print("Done:", done, "Truncated:", truncated)

env.close()
# Out:
# Initial observation shape: (8,)
# Next observation shape: (8,)
# Reward: -0.8033619055678674
# Done: False Truncated: False
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
# 5. Training a PPO Agent and Evaluating Performance
# PPO: A popular on-policy algorithm for continuous or discrete action spaces.
# Hyperparameters: Adjust batch_size, learning_rate, and n_steps to potentially improve learning.
# Training: I run 200,000 timesteps this time.
# Evaluation: I test the model on a number of episodes (here 5), compute the average return, and print the result.

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# Create the environment and wrap it in a DummyVecEnv
env = gym.make("LunarLander-v2", render_mode="rgb_array")
vec_env = DummyVecEnv([lambda: env])

# Initialize the PPO model with some chosen hyperparameters
model = PPO(
    "MlpPolicy",
    vec_env,
    verbose=1,
    batch_size=64,        # more detatailed..
    learning_rate=3e-4,   # default
    n_steps=2048          # default
)

# Train the model for 200,000 timesteps
model.learn(total_timesteps=200000)
print("Training complete")

import numpy as np

# Define an evaluation function
def evaluate_model(model, env, n_eval_episodes=5):
    rewards_list = []
    for _ in range(n_eval_episodes):
        obs, _ = env.reset()
        done, truncated = False, False
        total_reward = 0
        while not (done or truncated):
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, truncated, _ = env.step(action)
            total_reward += reward
        rewards_list.append(total_reward)
    return np.mean(rewards_list)

# Evaluate the trained model on 5 episodes
mean_reward = evaluate_model(model, env)
print("Number of evaluation episodes:", 5, "Mean reward::", mean_reward)
env.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:604: UserWarning: WARN: plugin: shimmy.registration:register_gymnasium_envs raised Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py", line 602, in load_plugin_envs
#     fn()
#   File "/usr/local/lib/python3.11/dist-packages/shimmy/registration.py", line 304, in register_gymnasium_envs
#     _register_atari_envs()
#   File "/usr/local/lib/python3.11/dist-packages/shimmy/registration.py", line 205, in _register_atari_envs
#     import ale_py
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/__init__.py", line 68, in <module>
#     register_v0_v4_envs()
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/registration.py", line 178, in register_v0_v4_envs
#     _register_rom_configs(legacy_games, obs_types, versions)
#   File "/usr/local/lib/python3.11/dist-packages/ale_py/registration.py", line 63, in _register_rom_configs
#     gymnasium.register(
#     ^^^^^^^^^^^^^^^^^^
# AttributeError: partially initialized module 'gymnasium' has no attribute 'register' (most likely due to a circular import)
#
#   logger.warn(f"plugin: {plugin.value} raised {traceback.format_exc()}")
# 2025-04-28 19:48:13.686214: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745869693.734631     988 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745869693.750005     988 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# /usr/local/lib/python3.11/dist-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 1058 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009390529 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00188    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 792         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 1.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0064479993 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0196      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 419          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00503     |
# |    value_loss           | 913          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010819269 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00276    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 262         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 626         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 697          |
# |    iterations           | 5            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0072051543 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0413      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 616          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00777     |
# |    value_loss           | 791          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 685          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0089187175 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.000731     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 382          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 573          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008026844 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.00752    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 187         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00989    |
# |    value_loss           | 373         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 669          |
# |    iterations           | 8            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0133302985 |
# |    clip_fraction        | 0.0649       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.000818    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 236          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 599          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 661        |
# |    iterations           | 9          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00840249 |
# |    clip_fraction        | 0.0495     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | -0.0244    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 162        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00716   |
# |    value_loss           | 443        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012408736 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.0016     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 123         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 251         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 11          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010805476 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | -0.000155   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 141         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 350         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 12          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010407081 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -6.39e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 182         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 342         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 13           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0069039646 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | -0.000114    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 235          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 14          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008299606 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | -0.000194   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00586    |
# |    value_loss           | 312         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 15           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0052602952 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.000513     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 276          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 16          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004601397 |
# |    clip_fraction        | 0.00557     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0244      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 207         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 17           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0031268569 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.0303       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 133          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 217          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 18           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0062529966 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.18         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.8         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00585     |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 19          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013669683 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 211         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 576          |
# |    iterations           | 20           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0069615133 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0825       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 144          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 285          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 568          |
# |    iterations           | 21           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0050808587 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 131          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 343          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 22          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005778026 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.1        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00884    |
# |    value_loss           | 181         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 23          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004838571 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 24          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004186686 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0534      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 321         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 25           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0072742244 |
# |    clip_fraction        | 0.0585       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48           |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0058      |
# |    value_loss           | 165          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 26          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005289151 |
# |    clip_fraction        | 0.0185      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 83          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 27          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008050909 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 160         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 28          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.003351259 |
# |    clip_fraction        | 0.0062      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 164         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 29          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014540207 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 62.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00912    |
# |    value_loss           | 140         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 30           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0055132136 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 101          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00447     |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 31          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004902929 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0447     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0041     |
# |    value_loss           | 88.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 504         |
# |    iterations           | 32          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009345369 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00879    |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 33          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010162076 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 66.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 34          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007067663 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.5        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 49.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 480          |
# |    iterations           | 35           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0113868015 |
# |    clip_fraction        | 0.169        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.7         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0151      |
# |    value_loss           | 34.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 36          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010209463 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.452       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 23.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 37          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006647325 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.16        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 38          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009311836 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 39          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011980454 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 451          |
# |    iterations           | 40           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0042143334 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.33         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 13.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 444         |
# |    iterations           | 41          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.003656013 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.904      |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.88        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00385    |
# |    value_loss           | 49.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 42          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015928863 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.38        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 43          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003496022 |
# |    clip_fraction        | 0.0629      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00438    |
# |    value_loss           | 8.65        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 436        |
# |    iterations           | 44         |
# |    time_elapsed         | 206        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00749958 |
# |    clip_fraction        | 0.0932     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.96      |
# |    explained_variance   | 0.438      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31.1       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00596   |
# |    value_loss           | 42.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 45          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.012893592 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 46.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 46          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007705015 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.52        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 40.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 47           |
# |    time_elapsed         | 221          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0022127056 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.6         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 187          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 48          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018895058 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 121         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 49           |
# |    time_elapsed         | 231          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0088638645 |
# |    clip_fraction        | 0.0594       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.96        |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 99           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 50          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.014154858 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.7        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 82          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 429         |
# |    iterations           | 51          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.010394035 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 34.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 52          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008359678 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.57        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 36.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 53          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010909949 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 54          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.014928137 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.8        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0051     |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 425         |
# |    iterations           | 55          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.010048132 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.06        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00255    |
# |    value_loss           | 16          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 56           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0056450847 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.76         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 40           |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 57         |
# |    time_elapsed         | 275        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.01025608 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.851     |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.3        |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.00702   |
# |    value_loss           | 8.5        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 58          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.008436964 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.9        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 70.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 59          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.010639666 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.11        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 7.39        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 60          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.013194423 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.859      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.94        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 6.54        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 61           |
# |    time_elapsed         | 300          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0024742759 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# ...
# |    iterations           | 78          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.006013342 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.7        |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 79          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 161792      |
# | train/                  |             |
# |    approx_kl            | 0.005086313 |
# |    clip_fraction        | 0.0939      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.86        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 94.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 80          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.006752692 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.4        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 93          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 416         |
# |    iterations           | 81          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.008018514 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.5         |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 50.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 82           |
# |    time_elapsed         | 402          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0051391427 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.626        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40           |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 95           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 83           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0073011164 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 62.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 84           |
# |    time_elapsed         | 412          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0055299383 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.906       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.8         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 121          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 417          |
# |    iterations           | 85           |
# |    time_elapsed         | 417          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0069794534 |
# |    clip_fraction        | 0.0696       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.6         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 117          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 415          |
# |    iterations           | 86           |
# |    time_elapsed         | 423          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0091514075 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.863       |
# |    explained_variance   | 0.533        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.9         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00401     |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 415         |
# |    iterations           | 87          |
# |    time_elapsed         | 428         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.015392194 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.824      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0031     |
# |    value_loss           | 117         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 88           |
# |    time_elapsed         | 434          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0032111914 |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.2         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000221    |
# |    value_loss           | 76.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 89           |
# |    time_elapsed         | 439          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0058829924 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.927       |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.7         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 70.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 90          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.008070864 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.961      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 22.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 413        |
# |    iterations           | 91         |
# |    time_elapsed         | 450        |
# |    total_timesteps      | 186368     |
# | train/                  |            |
# |    approx_kl            | 0.00470834 |
# |    clip_fraction        | 0.0549     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.917     |
# |    explained_variance   | 0.8        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 41.7       |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.00394   |
# |    value_loss           | 46.9       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 92           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0069841812 |
# |    clip_fraction        | 0.057        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.905       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.6         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 59.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 93          |
# |    time_elapsed         | 460         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006278315 |
# |    clip_fraction        | 0.0514      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 94          |
# |    time_elapsed         | 465         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.005176718 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.4        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00221    |
# |    value_loss           | 79.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 95          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.004526055 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.61        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 40.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 96           |
# |    time_elapsed         | 474          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0034234407 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17           |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 72.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 97           |
# |    time_elapsed         | 479          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0038687796 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.692        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 83.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 98          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.006825449 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 39.4        |
# -----------------------------------------
# Training complete
# Number of evaluation episodes: 5 Mean reward:: 140.526294586517
